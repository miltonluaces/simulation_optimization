# %% [markdown]
# # Time series simulation

# %%
import sys
sys.path.append('D:/source/repos')
from utilities.std_imports import *
import pandas_montecarlo
from pandas_datareader import data

# %% [markdown]
# ### Load data

# %%
data = data.get_data_yahoo('AAPL', '2017-01-01', '2018-01-01')
ts = data.Close.pct_change()
plt.plot(ts);

# %% [markdown]
# ### Monte Carlo simulation

# %%
mc = ts.montecarlo(sims=5)

# %%
mc.data.head()
# Out:
#    original         1         2         3         4
# 0       NaN  0.004111 -0.001318  0.007997 -0.000290
# 1 -0.001119  0.027188  0.001292  0.019484 -0.000999
# 2  0.005085  0.009517  0.013929 -0.014000  0.000378
# 3  0.011148  0.003785  0.001731 -0.002302 -0.004175
# 4  0.009159 -0.014743  0.022508 -0.006160  0.007997

# %%
mc.stats
# Out:
# {'min': 0.3920766537825092,
#  'max': 0.3920766537825092,
#  'mean': 0.3920766537825092,
#  'median': 0.3920766537825092,
#  'std': 0.0,
#  'maxdd': -0.005261638678814129,
#  'bust': 0.0,
#  'goal': 1.0}

# %%
mc.plot(figsize=[20,10]);

# %% [markdown]
# ### Credits & Links

# %% [markdown]
# https://github.com/ranaroussi/pandas-montecarlo
